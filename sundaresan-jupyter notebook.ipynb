# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

csv,text,tsv

comma separates values

tab separated values

# %%
#To read csv file

df = pd.read_csv(r"C:\Users\SUNDARESAN.A\Downloads\loan_prediction[1].csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes          1      Graduate            No
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 606  LP002961    Male     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
df.sample()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 386  LP002239   Male      No          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 386             2346             1600.0       132.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 386             1.0     Semiurban           Y

# %%
df.sample(7)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 270  LP001888  Female      No          0  Graduate            No
# 286  LP001925  Female      No          0  Graduate           Yes
# 143  LP001507    Male     Yes          0  Graduate            No
# 255  LP001846  Female      No         3+  Graduate            No
# 133  LP001482    Male     Yes          0  Graduate           Yes
# 495  LP002586  Female     Yes          1  Graduate            No
# 136  LP001489  Female     Yes          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 270             3237                0.0        30.0             360.0
# 286             2600             1717.0        99.0             300.0
# 143             2698             2034.0       122.0             360.0
# 255             3083                0.0       255.0             360.0
# 133             3459                0.0        25.0             120.0
# ...

# %%
df = pd.read_csv(r"C:\Users\SUNDARESAN.A\Downloads\loan_prediction[1].csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['Loan_ID']
# Out:
# 0      LP001002
# 1      LP001003
# 2      LP001005
# 3      LP001006
# 4      LP001008
#          ...
# 609    LP002978
# 610    LP002979
# 611    LP002983
# 612    LP002984
# 613    LP002990
# Name: Loan_ID, Length: 614, dtype: object

# %%
df['Gender'][3]
# Out:
# 'Male'

# %%
 df['Education'][610]
# Out:
# 'Graduate'

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame

# %%
df
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.DataFrame([1,2,3,4,5], index = [10,20,30,40,50])

# %%
df
# Out:
#     0
# 10  1
# 20  2
# 30  3
# 40  4
# 50  5

# %%
df = pd.read_csv(r"C:\Users\SUNDARESAN.A\Downloads\loan_prediction[1].csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
dict1 ={'Loan_ID': 100,'Gender':'Male'}

# %%
e = pd.Series(dict1)

# %%
e
# Out:
# Loan_ID     100
# Gender     Male
# dtype: object

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.read_csv(r"C:\Users\SUNDARESAN.A\Downloads\loan_prediction[1].csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.drop(['Dependents','Education'], axis=1, inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 0    LP001002    Male      No            No             5849
# 1    LP001003    Male     Yes            No             4583
# 2    LP001005    Male     Yes           Yes             3000
# 3    LP001006    Male     Yes            No             2583
# 4    LP001008    Male      No            No             6000
# ..        ...     ...     ...           ...              ...
# 609  LP002978  Female      No            No             2900
# 610  LP002979    Male     Yes            No             4106
# 611  LP002983    Male     Yes            No             8072
# 612  LP002984    Male     Yes            No             7583
# 613  LP002990  Female      No           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                  0.0         NaN             360.0             1.0
# 1               1508.0       128.0             360.0             1.0
# ...

# %%
df['Loan_Amount_Term'].describe()
# Out:
# count    600.00000
# mean     342.00000
# std       65.12041
# min       12.00000
# 25%      360.00000
# 50%      360.00000
# 75%      360.00000
# max      480.00000
# Name: Loan_Amount_Term, dtype: float64

# %%
df['Gender'].describe()
# Out:
# count      601
# unique       2
# top       Male
# freq       489
# Name: Gender, dtype: object

# %%
df.describe(include ='all')
# Out:
#          Loan_ID Gender Married Self_Employed  ApplicantIncome  \
# count        614    601     611           582       614.000000
# unique       614      2       2             2              NaN
# top     LP001002   Male     Yes            No              NaN
# freq           1    489     398           500              NaN
# mean         NaN    NaN     NaN           NaN      5403.459283
# std          NaN    NaN     NaN           NaN      6109.041673
# min          NaN    NaN     NaN           NaN       150.000000
# 25%          NaN    NaN     NaN           NaN      2877.500000
# 50%          NaN    NaN     NaN           NaN      3812.500000
# 75%          NaN    NaN     NaN           NaN      5795.000000
# max          NaN    NaN     NaN           NaN     81000.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# count          614.000000  592.000000         600.00000      564.000000
# ...

# %%
df.dropna(inplace= True)

# %%
df
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes            No             4583
# 2    LP001005    Male     Yes           Yes             3000
# 3    LP001006    Male     Yes            No             2583
# 4    LP001008    Male      No            No             6000
# 5    LP001011    Male     Yes           Yes             5417
# ..        ...     ...     ...           ...              ...
# 609  LP002978  Female      No            No             2900
# 610  LP002979    Male     Yes            No             4106
# 611  LP002983    Male     Yes            No             8072
# 612  LP002984    Male     Yes            No             7583
# 613  LP002990  Female      No           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
df.drop_duplicates(inplace = True)

# %%
df
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes            No             4583
# 2    LP001005    Male     Yes           Yes             3000
# 3    LP001006    Male     Yes            No             2583
# 4    LP001008    Male      No            No             6000
# 5    LP001011    Male     Yes           Yes             5417
# ..        ...     ...     ...           ...              ...
# 609  LP002978  Female      No            No             2900
# 610  LP002979    Male     Yes            No             4106
# 611  LP002983    Male     Yes            No             8072
# 612  LP002984    Male     Yes            No             7583
# 613  LP002990  Female      No           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# ...

# %%
df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes            No             4583
# 2    LP001005    Male     Yes           Yes             3000
# 3    LP001006    Male     Yes            No             2583
# 4    LP001008    Male      No            No             6000
# 5    LP001011    Male     Yes           Yes             5417
# ..        ...     ...     ...           ...              ...
# 609  LP002978  Female      No            No             2900
# 610  LP002979    Male     Yes            No             4106
# 611  LP002983    Male     Yes            No             8072
# 612  LP002984    Male     Yes            No             7583
# 613  LP002990  Female      No           Yes             4583
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 1               1508.0       128.0             360.0             1.0
# 2                  0.0        66.0             360.0             1.0
# ...

# %%
df.duplicated()
# Out:
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 609    False
# 610    False
# 611    False
# 612    False
# 613    False
# Length: 490, dtype: bool

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
df['Property_Area'].nunique()
# Out:
# 3

# %%
df.nunique()
# Out:
# Loan_ID              490
# Gender                 2
# Married                2
# Self_Employed          2
# ApplicantIncome      413
# CoapplicantIncome    234
# LoanAmount           186
# Loan_Amount_Term       9
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    194
# Urban        155
# Rural        141
# Name: Property_Area, dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Property_Area'].unique()
# Out:
# array(['Rural', 'Urban', 'Semiurban'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Gender'][7]
# Out:
# 'Male'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 490 entries, 1 to 613
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            490 non-null    object
#  1   Gender             490 non-null    object
#  2   Married            490 non-null    object
#  3   Self_Employed      490 non-null    object
#  4   ApplicantIncome    490 non-null    int64
#  5   CoapplicantIncome  490 non-null    float64
#  6   LoanAmount         490 non-null    float64
#  7   Loan_Amount_Term   490 non-null    float64
#  8   Credit_History     490 non-null    float64
#  9   Property_Area      490 non-null    object
#  10  Loan_Status        490 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 62.1+ KB

# %%
df.iloc[:,3:5]
# Out:
#     Self_Employed  ApplicantIncome
# 1              No             4583
# 2             Yes             3000
# 3              No             2583
# 4              No             6000
# 5             Yes             5417
# ..            ...              ...
# 609            No             2900
# 610            No             4106
# 611            No             8072
# 612            No             7583
# 613           Yes             4583
#
# [490 rows x 2 columns]

# %%
df.iloc[0:5,:7]
# Out:
#     Loan_ID Gender Married Self_Employed  ApplicantIncome  CoapplicantIncome  \
# 1  LP001003   Male     Yes            No             4583             1508.0
# 2  LP001005   Male     Yes           Yes             3000                0.0
# 3  LP001006   Male     Yes            No             2583             2358.0
# 4  LP001008   Male      No            No             6000                0.0
# 5  LP001011   Male     Yes           Yes             5417             4196.0
#
#    LoanAmount
# 1       128.0
# 2        66.0
# 3       120.0
# 4       141.0
# 5       267.0

# %%
df.shape
# Out:
# (490, 11)

# %%
print("Number of rows:",df.shape[0])
# Out:
# Number of rows: 490

# %%
df.iloc[:,-7]
# Out:
# 1      4583
# 2      3000
# 3      2583
# 4      6000
# 5      5417
#        ...
# 609    2900
# 610    4106
# 611    8072
# 612    7583
# 613    4583
# Name: ApplicantIncome, Length: 490, dtype: int64

# %%
df.iloc[7:9, 0:3]
# Out:
#     Loan_ID Gender Married
# 8  LP001018   Male     Yes
# 9  LP001020   Male     Yes

# %%
df.iloc[1:7, 10:]
# Out:
#   Loan_Status
# 2           Y
# 3           Y
# 4           Y
# 5           Y
# 6           Y
# 7           N

# %%
df.loc[:,"Loan_ID"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9460\462114420.py in <module>
# ----> 1 df.loc[:,"Loan_ID"]
#
# NameError: name 'df' is not defined

# %%
df.loc[0:7,"Loan_ID"]
# Out:
# 1    LP001003
# 2    LP001005
# 3    LP001006
# 4    LP001008
# 5    LP001011
# 6    LP001013
# 7    LP001014
# Name: Loan_ID, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9460\2238265732.py in <module>
# ----> 1 df.loc[0:9],['Loan_ID','Gender']
#
# NameError: name 'df' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9460\1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
